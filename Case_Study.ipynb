# %%
import json
import re
import ast
import sys
import nltk
import traceback
import astor
import token as tk
from tokenize import generate_tokens
from io import StringIO
import itertools 
from gensim.models import FastText
from gensim.models import KeyedVectors
from time import time
import numpy as np
import pickle

# %%
# File Path
test_path="data/conala-corpus/conala-test.json"
test_clean_output_path="data/conala-corpus/.test.seq2seq"

# most relevant document path 
fasttext_path = 'test_list_most_relevant_doc_fasttext.pkl'
supervised_path = 'test_list_most_relevant_doc_super.pkl'
unsupervised_path = 'test_list_most_relevant_doc_unsuper.pkl'

# %%
QUOTED_STRING_RE = re.compile(r"(?P<quote>[`'\"])(?P<string>.*?)(?P=quote)")


def canonicalize_intent(intent):
    str_matches = QUOTED_STRING_RE.findall(intent)

    slot_map = dict()

    return intent, slot_map


def replace_strings_in_ast(py_ast, string2slot):
    for node in ast.walk(py_ast):
        for k, v in list(vars(node).items()):
            if k in ('lineno', 'col_offset', 'ctx'):
                continue
            # Python 3
            # if isinstance(v, str) or isinstance(v, unicode):
            if isinstance(v, str):
                if v in string2slot:
                    val = string2slot[v]
                    # Python 3
                    # if isinstance(val, unicode):
                    #     try: val = val.encode('ascii')
                    #     except: pass
                    setattr(node, k, val)
                else:
                    # Python 3
                    # if isinstance(v, str):
                    #     str_key = unicode(v)
                    # else:
                    #     str_key = v.encode('utf-8')
                    str_key = v

                    if str_key in string2slot:
                        val = string2slot[str_key]
                        if isinstance(val, str):
                            try: val = val.encode('ascii')
                            except: pass
                        setattr(node, k, val)


def canonicalize_code(code, slot_map):
    string2slot = {x[1]['value']: x[0] for x in list(slot_map.items())}

    py_ast = ast.parse(code)
    replace_strings_in_ast(py_ast, string2slot)
    canonical_code = astor.to_source(py_ast)

    return canonical_code


def decanonicalize_code(code, slot_map):
    try:
        slot2string = {x[0]: x[1]['value'] for x in list(slot_map.items())}
        py_ast = ast.parse(code)
        replace_strings_in_ast(py_ast, slot2string)
        raw_code = astor.to_source(py_ast)
      # for slot_name, slot_info in slot_map.items():
      #     raw_code = raw_code.replace(slot_name, slot_info['value'])

        return raw_code.strip()
    except:
        return code

def detokenize_code(code_tokens):
    newline_pos = [i for i, x in enumerate(code_tokens) if x == '\n']
    newline_pos.append(len(code_tokens))
    start = 0
    lines = []
    for i in newline_pos:
        line = ' '.join(code_tokens[start: i])
        start = i + 1
        lines.append(line)

    code = '\n'.join(lines).strip()

    return code


def encode_tokenized_code(code_tokens):
    tokens = []
    for token in code_tokens:
        if token == '\t':
            tokens.append('_TAB_')
        elif token == '\n':
            tokens.append('_NEWLINE_')


def get_encoded_code_tokens(code):
    code = code.strip()
    #print(code)
    token_stream = generate_tokens(StringIO(code).readline)
    tokens = []
    indent_level = 0
    new_line = False

    for toknum, tokval, (srow, scol), (erow, ecol), _ in token_stream:
        if toknum == tk.NEWLINE:
            tokens.append('#NEWLINE#')
            new_line = True
        elif toknum == tk.INDENT:
            indent_level += 1
            # new_line = False
            # for i in range(indent_level):
            #     tokens.append('#INDENT#')
        elif toknum == tk.STRING:
            tokens.append(tokval.replace(' ', '#SPACE#').replace('\t', '#TAB#').replace('\r\n', '#NEWLINE#').replace('\n', '#NEWLINE#'))
        elif toknum == tk.DEDENT:
            indent_level -= 1
            # for i in range(indent_level):
            #     tokens.append('#INDENT#')
            # new_line = False
        else:
            tokval = tokval.replace('\n', '#NEWLINE#')
            if new_line:
                for i in range(indent_level):
                    tokens.append('#INDENT#')

            new_line = False
            tokens.append(tokval)

    # remove ending None
    if len(tokens[-1]) == 0:
        tokens = tokens[:-1]

    if '\n' in tokval:
        pass

    return tokens


def tokenize(code):
    token_stream = generate_tokens(StringIO(code).readline)
    tokens = []
    for toknum, tokval, (srow, scol), (erow, ecol), _ in token_stream:
        if toknum == tk.ENDMARKER:
            break

        tokens.append(tokval)

    return tokens


def compare_ast(node1, node2):
    # Python 3
    # if not isinstance(node1, str) and not isinstance(node1, unicode):
    if not isinstance(node1, str):
        if type(node1) is not type(node2):
            return False
    if isinstance(node1, ast.AST):
        for k, v in list(vars(node1).items()):
            if k in ('lineno', 'col_offset', 'ctx'):
                continue
            if not compare_ast(v, getattr(node2, k)):
                return False
        return True
    elif isinstance(node1, list):
        return all(itertools.starmap(compare_ast, zip(node1, node2)))
    else:
        return node1 == node2


def encoded_code_tokens_to_code(encoded_tokens, indent=' '):
    decoded_tokens = []
    for i in range(len(encoded_tokens)):
        token = encoded_tokens[i]
        token = token.replace('#TAB#', '\t').replace('#SPACE#', ' ')

        if token == '#INDENT#': decoded_tokens.append(indent)
        elif token == '#NEWLINE#': decoded_tokens.append('\n')
        else:
            token = token.replace('#NEWLINE#', '\n')
            decoded_tokens.append(token)
            decoded_tokens.append(' ')

    code = ''.join(decoded_tokens).strip()

    return code


def find_sub_sequence(sequence, query_seq):
    for i in range(len(sequence)):
        if sequence[i: len(query_seq) + i] == query_seq:
            return i, len(query_seq) + i

    raise IndexError


def replace_sequence(sequence, old_seq, new_seq):
    matched = False
    for i in range(len(sequence)):
        if sequence[i: i + len(old_seq)] == old_seq:
            matched = True
            sequence[i:i + len(old_seq)] = new_seq
    return matched

# %%
# read and clean data
def read_clean_dataset(dataset_path, output_path):
    train = json.load(open(dataset_path))

    for i, example in enumerate(train):
        # updating `train` in place
        intent = example['intent']

        rewritten_intent = example['rewritten_intent']

        snippet = example['snippet']
        # print(i)
        # code_tokens = get_encoded_code_tokens(snippet)
        # print(' '.join(code_tokens))

        failed = False
        intent_tokens = []
        if rewritten_intent:
            try:
                canonical_intent, slot_map = canonicalize_intent(rewritten_intent)
                #print(canonical_intent, slot_map)

                snippet = snippet
                canonical_snippet = canonicalize_code(snippet, slot_map)
                #print("canonical_snippet:", canonical_snippet, slot_map)

                intent_tokens = nltk.word_tokenize(canonical_intent)

                decanonical_snippet = decanonicalize_code(canonical_snippet, slot_map)
                #print("decanonical_snippet: ",decanonical_snippet)

                snippet_reconstr = astor.to_source(ast.parse(snippet)).strip()
                #print("snippet_reconstr: ",decanonical_snippet)

                decanonical_snippet_reconstr = astor.to_source(ast.parse(decanonical_snippet)).strip()
                #print("decanonical_snippet_reconstr: ",decanonical_snippet_reconstr)
                encoded_reconstr_code = get_encoded_code_tokens(decanonical_snippet_reconstr)
                decoded_reconstr_code = encoded_code_tokens_to_code(encoded_reconstr_code)

                # syntax error in snippet
                if not compare_ast(ast.parse(decoded_reconstr_code), ast.parse(snippet)):
                    print(i)
                    print('Original Snippet: %s' % snippet_reconstr)
                    print('Tokenized Snippet: %s' % ' '.join(encoded_reconstr_code))
                    print('decoded_reconstr_code: %s' % decoded_reconstr_code)

            except:
                print('*' * 20, file=sys.stderr)
                print(i, file=sys.stderr)
                print(intent, file=sys.stderr)
                print(snippet, file=sys.stderr)
                traceback.print_exc()

                failed = True
            finally:
                example['slot_map'] = slot_map

        if rewritten_intent is None:
            encoded_reconstr_code = get_encoded_code_tokens(snippet.strip())
        else:
            encoded_reconstr_code = get_encoded_code_tokens(canonical_snippet.strip())

        if not intent_tokens:
            intent_tokens = nltk.word_tokenize(intent)

        example['intent_tokens'] = intent_tokens
        example['snippet_tokens'] = encoded_reconstr_code

    json.dump(train, open(output_path, 'w'), indent=2)

# %% [markdown]
# ## Print Case

# %%
def print_result(list_most_relevant_doc, ques_list):

    # save the correct idx which one of ten result match correct code snippet 
    index_list = []
    
    # save the ranking position which the best answer in
    ranking_list = []

    for j, ques_sim_dict in enumerate(list_most_relevant_doc):
        for pid, idx in enumerate(ques_sim_dict['similar']):
            if ques_list[idx]['question_id'] == ques_sim_dict['question_id']:
                index_list.append(j)
                ranking_list.append(pid)
                break

    return index_list, ranking_list

# %%
read_clean_dataset(test_path, test_clean_output_path)
test_clean = json.load(open(test_clean_output_path))

test_size=len(test_clean)
test_ques_list=[] # [{"question_id": int, "intent_tokens": [...]}, ...]

for idx, example in enumerate(test_clean):
    test_ques_list.append({"question_id": example["question_id"], "intent_tokens": example["intent_tokens"]})

# %%
with open(fasttext_path, 'rb') as f:
    fasttext_doc = pickle.load(f)
    
with open(supervised_path, 'rb') as f:
    supervised_doc = pickle.load(f)
    
with open(unsupervised_path, 'rb') as f:
    unsupervised_doc = pickle.load(f)

# %%
f_idx_list, f_ranking_list= print_result(fasttext_doc, test_ques_list)
print(len(f_idx_list))

s_idx_list, s_ranking_list= print_result(supervised_doc, test_ques_list)
print(len(s_idx_list))

u_idx_list, u_ranking_list= print_result(unsupervised_doc, test_ques_list)
print(len(u_idx_list))
# Out:
# 81
# 332
# 237

# %%
# save the id that only supervised learning correctly match
final_idx = []
for i, j in enumerate(s_idx_list):
    if j not in f_idx_list and j not in u_idx_list:
        final_idx.append((i,j))

# %%
len(final_idx)
# Out:
# 111

# %%
for (pid, idx) in final_idx:
    print(idx, test_clean[idx]['question_id'])
    print(test_clean[idx]['intent'])
    print(test_clean[idx]['snippet'])
    print(s_ranking_list[pid])
    print("")
    
    print("##FastText###")
    for j, z in enumerate(fasttext_doc[idx]['similar']):
        print(j+1 , test_clean[z]['snippet'])
    
    print("##SuperVised Starspace###")
    
    for j, z in enumerate(supervised_doc[idx]['similar']):
        print(j+1 , test_clean[z]['snippet'])
         
    print("##UnsuperVised Starspace###")
    
    for j, z in enumerate(unsupervised_doc[idx]['similar']):
        print(j+1 , test_clean[z]['snippet'])
    
    print("##Done###")
    print("")
# Out:
# 4 7555335
# How to convert a string from CP-1251 to UTF-8?
# d.decode('cp1251').encode('utf8')
# 0
#
# ##FastText###
# 1 l = sorted(l, key=lambda a: a['time'], reverse=True)
# 2 df.to_csv('c:\\data\\pandas.txt', header=None, index=None, sep=' ', mode='a')
# 3 generator = iter_iprange('192.168.1.1', '192.168.255.255', step=1)
# 4 r = requests.post(url, files=files, headers=headers, data=data)
# 5 b = models.CharField(max_length=7, default='0000000', editable=False)
# 6 result = ([a for (a, b) in original], [b for (a, b) in original])
# 7 requests.post(url, data=DATA, headers=HEADERS_DICT, auth=(username, password))
# 8 df['group'].plot(kind='bar', color=['r', 'g', 'b', 'r', 'g', 'b', 'r'])
# 9 parser.add_argument('--version', action='version', version='%(prog)s 2.0')
# 10 df.xs('sat', level='day', drop_level=False)
# ##SuperVised Starspace###
# 1 d.decode('cp1251').encode('utf8')
# 2 Counter(' '.join(df['text']).split()).most_common(100)
# 3 [m.group(0) for m in re.finditer('(\\d)\\1*', s)]
# 4 plt.scatter(np.random.randn(100), np.random.randn(100), facecolors='none')
# 5 plt.plot(np.random.randn(100), np.random.randn(100), 'o', mfc='none')
# 6 print(soup.find(text='Address:').findNext('td').contents[0])
# 7 'Sopet\xc3\xb3n'.encode('latin-1').decode('utf-8')
# 8 np.array(zip(a.ravel(), b.ravel()), dtype='i4,i4').reshape(a.shape)
# 9 df.replace({'\n': '<br>'}, regex=True)
# 10 df.replace({'\n': '<br>'}, regex=True)
# ##UnsuperVised Starspace###
# 1 sorted(list(x.items()), key=lambda pair: pair[1], reverse=True)
# 2 {k: [d[k] for d in dicts] for k in dicts[0]}
# 3 l = sorted(l, key=lambda a: a['time'], reverse=True)
# 4 dict((k, [d[k] for d in dicts]) for k in dicts[0])
# 5 sorted(x, key=x.get, reverse=True)
# 6 int(round(2.51 * 100))
# 7 max(k for k, v in x.items() if v != 0)
# 8 max(k for k, v in x.items() if v != 0)
# 9 ut.sort(key=lambda x: x.count, reverse=True)
# 10 ut.sort(key=lambda x: x.count, reverse=True)
# ##Done###
#
# 7 14971373
# Python: how to get the final output of multiple system commands?
# subprocess.check_output('ps -ef | grep something | wc -l', shell=True)
# 7
#
# ##FastText###
# 1 len(s)
# 2 s.encode('iso-8859-15')
# 3 list(t)
# 4 (type(o) is str)
# 5 len(my_list)
# 6 any(key.startswith('EMP$$') for key in dict1)
# 7 s.split(' ', 4)
# 8 list(set(t))
# 9 input('Enter your input:')
# 10 list(set(source_list))
# ##SuperVised Starspace###
# 1 subprocess.call(['python.exe', 'hello.py', 'htmlfilename.htm'])
# 2 subprocess.call(['/usr/bin/Rscript', '--vanilla', '/pathto/MyrScript.r'])
# 3 subprocess.Popen(['background-process', 'arguments'])
# 4 subprocess.call('sleep.sh', shell=True)
# 5 subprocess.call('/usr/bin/Rscript --vanilla /pathto/MyrScript.r', shell=True)
# 6 subprocess.call(['notepad'])
# 7 subprocess.call(['./test.sh'])
# 8 subprocess.check_output('ps -ef | grep something | wc -l', shell=True)
# 9 subprocess.check_call('vasp | tee tee_output', shell=True)
# 10 subprocess.Popen(['c:\\Program Files\\VMware\\VMware Server\\vmware-cmd.bat'])
# ##UnsuperVised Starspace###
# 1 del d['ele']
# 2 df.groupby('id').first()
# 3 os.system('gnome-terminal -e \'bash -c "sudo apt-get update; exec bash"\'')
# 4 os.system('powershell.exe', 'script.ps1')
# 5 'abcd}def}'.rfind('}')
# 6 subprocess.call(['./test.sh'])
# 7 subprocess.call(['notepad'])
# 8 subprocess.call(['/usr/bin/Rscript', '--vanilla', '/pathto/MyrScript.r'])
# 9 subprocess.call(['python.exe', 'hello.py', 'htmlfilename.htm'])
# 10 """ """.join(content.split(' ')[:-1])
# ##Done###
#
# 8 6726636
# splitting and concatenating a string
# """""".join(['a', 'b', 'c'])
# 2
#
# ##FastText###
# 1 values = sum([['A', 'B', 'C'], ['D', 'E', 'F'], ['G', 'H', 'I']], [])
# 2 matrix = [[a, b], [c, d], [e, f]]
# 3 df['group'].plot(kind='bar', color=['r', 'g', 'b', 'r', 'g', 'b', 'r'])
# 4 df['D'] = df['B']
# 5 generator = iter_iprange('192.168.1.1', '192.168.255.255', step=1)
# 6 result = ([a for (a, b) in original], [b for (a, b) in original])
# 7 my_list = []
# 8 np.maximum([2, 3, 4], [1, 5, 2])
# 9 l = sorted(l, key=lambda a: a['time'], reverse=True)
# 10 """""".join(['A', 'B', 'C', 'D'])
# ##SuperVised Starspace###
# 1 result = ([a for (a, b) in original], [b for (a, b) in original])
# 2 matrix = [[a, b], [c, d], [e, f]]
# 3 """""".join(['a', 'b', 'c'])
# 4 print(concatenate((a, b), axis=0))
# 5 result = ((a for (a, b) in original), (b for (a, b) in original))
# 6 print(concatenate((a, b), axis=1))
# 7 zip(*[('a', 1), ('b', 2), ('c', 3), ('d', 4)])
# 8 zip(*[('a', 1), ('b', 2), ('c', 3), ('d', 4)])
# 9 c = np.r_[(a[None, :], b[None, :])]
# 10 map(None, *[('a', 1), ('b', 2), ('c', 3), ('d', 4), ('e',)])
# ##UnsuperVised Starspace###
# 1 float('123,456.908'.replace(',', ''))
# 2 df.replace({'\n': '<br>'}, regex=True)
# 3 df.replace({'\n': '<br>'}, regex=True)
# 4 print('lamp, bag, mirror'.replace('bag,', ''))
# 5 sum(1 << i for i, b in enumerate(x) if b)
# 6 """it is icy""".replace('i', '')
# 7 df.to_csv('c:\\data\\pandas.txt', header=None, index=None, sep=' ', mode='a')
# 8 print(concatenate((a, b), axis=1))
# 9 print(concatenate((a, b), axis=0))
# 10 df['range'].replace(',', '-', inplace=True)
# ##Done###
#
# 16 13567345
# How to calculate the sum of all columns of a 2D numpy array (efficiently)
# a.sum(axis=1)
# 2
#
# ##FastText###
# 1 y = [[] for n in range(2)]
# 2 [index for index, item in enumerate(thelist) if item[0] == '332']
# 3 sum(1 << i for i, b in enumerate(x) if b)
# 4 c2.sort(key=lambda row: row[2])
# 5 [sum(row[i] for row in array) for i in range(len(array[0]))]
# 6 [image for menuitem in list_of_menuitems for image in menuitem]
# 7 sum(sum(i) if isinstance(i, list) else i for i in L)
# 8 c2.sort(key=lambda row: (row[2], row[1]))
# 9 [element for element in lst if not isinstance(element, str)]
# 10 lst = [Object() for i in range(100)]
# ##SuperVised Starspace###
# 1 numpy.array(a).reshape(-1).tolist()
# 2 df.astype(bool).sum(axis=1)
# 3 a.sum(axis=1)
# 4 np.array(zip(a.ravel(), b.ravel()), dtype='i4,i4').reshape(a.shape)
# 5 np.where(np.in1d(A, [1, 3, 4]).reshape(A.shape), A, 0)
# 6 np.savetxt('c:\\data\\np.txt', df.values, fmt='%d')
# 7 data.reshape(-1, j).mean(axis=1).reshape(data.shape[0], -1)
# 8 np.vstack((A, B))
# 9 np.concatenate((A, B))
# 10 df.groupby('prots').sum().sort('scores', ascending=False)
# ##UnsuperVised Starspace###
# 1 """The big brown fox is brown""".count('brown')
# 2 my_dict.update((x, y * 2) for x, y in list(my_dict.items()))
# 3 np.array((a, b))
# 4 [sum(row[i] for row in array) for i in range(len(array[0]))]
# 5 dict(((x, l.count(x)) for x in set(l)))
# 6 [int(1000 * random.random()) for i in range(10000)]
# 7 [[x, l.count(x)] for x in set(l)]
# 8 np.array([zip(x, y) for x, y in zip(a, b)])
# 9 print(concatenate((a, b), axis=0))
# 10 matrix = [[a, b], [c, d], [e, f]]
# ##Done###
#
# 24 2195340
# Determining the unmatched portion of a string using a regex in Python
# re.split('(\\W+)', 'Words, words, words.')
# 0
#
# ##FastText###
# 1 text = re.sub('^https?:\\/\\/.*[\\r\\n]*', '', text, flags=re.MULTILINE)
# 2 df['range'].replace(',', '-', inplace=True)
# 3 scipy.tensordot(P, T, axes=[1, 1]).swapaxes(0, 1)
# 4 """""".join(['A', 'B', 'C', 'D'])
# 5 pd.merge(split_df, csv_df, on=['key'], suffixes=('_left', '_right'))
# 6 subprocess.call(['/usr/bin/Rscript', '--vanilla', '/pathto/MyrScript.r'])
# 7 subprocess.call(['python.exe', 'hello.py', 'htmlfilename.htm'])
# 8 text = re.sub('\\b(\\w+)( \\1\\b)+', '\\1', text)
# 9 a[:, (np.newaxis)]
# 10 df.to_sql('test', engine, schema='a_schema')
# ##SuperVised Starspace###
# 1 re.split('(\\W+)', 'Words, words, words.')
# 2 re.split(' +', 'hello world sample text')
# 3 re.findall('"(http.*?)"', s, re.MULTILINE | re.DOTALL)
# 4 re.split('[ ](?=[A-Z])', input)
# 5 re.split('[ ](?=[A-Z]+\\b)', input)
# 6 re.split('(\\W+)', s)
# 7 re.search('(?<!Distillr)\\\\AcroTray\\.exe', 'C:\\SomeDir\\AcroTray.exe')
# 8 mystring.replace(' ', '! !').split('!')
# 9 re.search('\\[(.*)\\]', your_string).group(1)
# 10 re.findall('(.*?)\\[.*?\\]', example_str)
# ##UnsuperVised Starspace###
# 1 df.replace({'\n': '<br>'}, regex=True)
# 2 df.replace({'\n': '<br>'}, regex=True)
# 3 float('123,456.908'.replace(',', ''))
# 4 map(int, eval(input('Enter the unfriendly numbers: ')))
# 5 print('lamp, bag, mirror'.replace('bag,', ''))
# 6 mystring.replace(' ', '_')
# 7 sorted(list_of_strings, key=lambda s: s.split(',')[1])
# 8 text.split(',')
# 9 """,""".join(l)
# 10 pd.merge(split_df, csv_df, on=['key'], suffixes=('_left', '_right'))
# ##Done###
#
# 25 17977584
# How to read data from Excel and write it to text file line by line?
# file = open('Output.txt', 'a')
# 0
#
# ##FastText###
# 1 open(path, 'r')
# 2 len(s)
# 3 list(t)
# 4 for file in os.listdir('/mydir'):
#     if file.endswith('.txt'):
#         pass
# 5 for line in mylog:
#     list1.append(line)
# 6 for (root, dirs, files) in os.walk('/mydir'):
#     for file in files:
#         if file.endswith('.txt'):
#             pass
# 7 os.chdir('/mydir')
# for file in glob.glob('*.txt'):
#     pass
# 8 r = requests.get(url)
# 9 for fn in os.listdir('.'):
#     if os.path.isfile(fn):
#         pass
# 10 s.encode('iso-8859-15')
# ##SuperVised Starspace###
# 1 file = open('Output.txt', 'a')
# 2 new_file = open('path/to/FILE_NAME.ext', 'w')
# 3 open('filename', 'wb').write(bytes_)
# 4 open(path, 'r')
# 5 f = open('yourfile.txt', 'w')
# 6 pickle.dump(mylist, open('save.txt', 'wb'))
# 7 open('outfile', 'w').write('#test firstline\n' + open('infile').read())
# 8 with open('somefile.txt', 'a') as the_file:
#     the_file.write('Hello\n')
# 9 data = [line.strip() for line in open('C:/name/MyDocuments/numbers', 'r')]
# 10 open(filename, 'w').close()
# ##UnsuperVised Starspace###
# 1 sys.path.append('/path/to/whatever')
# 2 my_list.append(12)
# 3 b.append((a[0][0], a[0][2]))
# 4 for line in mylog:
#     list1.append(line)
# 5 zip(*[('a', 1), ('b', 2), ('c', 3), ('d', 4), ('e',)])
# 6 f = open('myfile', 'w')
# f.write('hi there\n')
# f.close()
# 7 df.index.get_loc('bob')
# 8 f = open('yourfile.txt', 'w')
# 9 zip(*[('a', 1), ('b', 2), ('c', 3), ('d', 4)])
# 10 zip(*[('a', 1), ('b', 2), ('c', 3), ('d', 4)])
# ##Done###
#
# 37 40133826
# Python save list and read data from file
# pickle.dump(mylist, open('save.txt', 'wb'))
# 1
#
# ##FastText###
# 1 file = open('Output.txt', 'a')
# 2 result = ((a for (a, b) in original), (b for (a, b) in original))
# 3 print('hi there', file=f)
# 4 f = open('yourfile.txt', 'w')
# 5 new_file = open('path/to/FILE_NAME.ext', 'w')
# 6 return HttpResponse(data, mimetype='application/json')
# 7 level1 = map(list, level1)
# 8 open(path, 'r')
# 9 newlist = sorted(l, key=itemgetter('name'), reverse=True)
# 10 l = sorted(l, key=itemgetter('time'), reverse=True)
# ##SuperVised Starspace###
# 1 with open('somefile.txt', 'a') as the_file:
#     the_file.write('Hello\n')
# 2 pickle.dump(mylist, open('save.txt', 'wb'))
# 3 file = open('Output.txt', 'a')
# 4 data = [line.strip() for line in open('C:/name/MyDocuments/numbers', 'r')]
# 5 open(path, 'r')
# 6 for file in os.listdir('/mydir'):
#     if file.endswith('.txt'):
#         pass
# 7 f = open('yourfile.txt', 'w')
# 8 new_file = open('path/to/FILE_NAME.ext', 'w')
# 9 response = requests.get(url, stream=True)
# with open('10MB', 'wb') as handle:
#     for data in tqdm(response.iter_content()):
#         handle.write(data)
# 10 for (root, dirs, files) in os.walk('/mydir'):
#     for file in files:
#         if file.endswith('.txt'):
#             pass
# ##UnsuperVised Starspace###
# 1 [x for x in mylist if len(x) == 3]
# 2 mylist.sort(key=lambda x: x['title'])
# 3 numlist = [float(x) for x in numlist]
# 4 if (not os.path.exists(directory)):
#     os.makedirs(directory)
# 5 [y for x in data for y in (x if isinstance(x, list) else [x])]
# 6 [x.strip() for x in '2.MATCHES $$TEXT$$ STRING'.split('$$TEXT$$')]
# 7 a[:] = [(x - 13) for x in a]
# 8 x = np.asarray(x).reshape(1, -1)[(0), :]
# 9 l.sort(key=lambda x: (x['title'], x['title_url'], x['id']))
# 10 L = [int(''.join([str(y) for y in x])) for x in L]
# ##Done###
#
# 39 2173087
# How to create nested lists in python?
# numpy.zeros((3, 3, 3))
# 4
#
# ##FastText###
# 1 len(s)
# 2 len(my_list)
# 3 (type(o) is str)
# 4 list(set(t))
# 5 list(t)
# 6 list(set(source_list))
# 7 any(key.startswith('EMP$$') for key in dict1)
# 8 len(my_tuple)
# 9 print(type(variable_name))
# 10 print('\n'.join('\t'.join(str(col) for col in row) for row in tab))
# ##SuperVised Starspace###
# 1 np.random.shuffle(np.transpose(r))
# 2 newFile.write(struct.pack('5B', *newFileBytes))
# 3 plt.plot(np.random.randn(100), np.random.randn(100), 'o', mfc='none')
# 4 plt.scatter(np.random.randn(100), np.random.randn(100), facecolors='none')
# 5 numpy.zeros((3, 3, 3))
# 6 answer = str(round(answer, 2))
# 7 numpy.array(a).reshape(-1).tolist()
# 8 np.where(np.in1d(A, [1, 3, 4]).reshape(A.shape), A, 0)
# 9 open('outfile', 'w').write('#test firstline\n' + open('infile').read())
# 10 np.vstack((A, B))
# ##UnsuperVised Starspace###
# 1 dict(((x, l.count(x)) for x in set(l)))
# 2 [[x, l.count(x)] for x in set(l)]
# 3 list(dict((x[0], x) for x in L).values())
# 4 my_dict.update((x, y * 2) for x, y in list(my_dict.items()))
# 5 list(set(t))
# 6 {k: [d[k] for d in dicts] for k in dicts[0]}
# 7 numlist = [float(x) for x in numlist]
# 8 dict((k, [d[k] for d in dicts]) for k in dicts[0])
# 9 [sum(row[i] for row in array) for i in range(len(array[0]))]
# 10 b.sort(key=lambda x: x[1][2])
# ##Done###
#
# 43 1592158
# Convert hex to float
# struct.unpack('!f', '470FC614'.decode('hex'))[0]
# 1
#
# ##FastText###
# 1 l = sorted(l, key=lambda a: a['time'], reverse=True)
# 2 result = ([a for (a, b) in original], [b for (a, b) in original])
# 3 generator = iter_iprange('192.168.1.1', '192.168.255.255', step=1)
# 4 matrix = [[a, b], [c, d], [e, f]]
# 5 df.to_csv('c:\\data\\pandas.txt', header=None, index=None, sep=' ', mode='a')
# 6 df['group'].plot(kind='bar', color=['r', 'g', 'b', 'r', 'g', 'b', 'r'])
# 7 values = sum([['A', 'B', 'C'], ['D', 'E', 'F'], ['G', 'H', 'I']], [])
# 8 parser.add_argument('--version', action='version', version='%(prog)s 2.0')
# 9 b = models.CharField(max_length=7, default='0000000', editable=False)
# 10 r = requests.post(url, files=files, headers=headers, data=data)
# ##SuperVised Starspace###
# 1 struct.unpack('H', struct.pack('h', number))
# 2 struct.unpack('!f', '470FC614'.decode('hex'))[0]
# 3 int()
# 4 int('1')
# 5 int(round(2.51 * 100))
# 6 newFile.write(struct.pack('5B', *newFileBytes))
# 7 float('123,456.908'.replace(',', ''))
# 8 user_list = [int(number) for number in user_input.split(',')]
# 9 map(int, eval(input('Enter the unfriendly numbers: ')))
# 10 target.write('%r\n%r\n%r\n' % (line1, line2, line3))
# ##UnsuperVised Starspace###
# 1 numlist = [float(x) for x in numlist]
# 2 float('123,456.908'.replace(',', ''))
# 3 user_list = [int(number) for number in user_input.split(',')]
# 4 my_float = float(my_string.replace(',', ''))
# 5 [x for x in mylist if len(x) == 3]
# 6 dict(((x, l.count(x)) for x in set(l)))
# 7 sum(int(float(item)) for item in [_f for _f in ['', '3.4', '', '', '1.0'] if _f])
# 8 pd.Series(list(set(s1).intersection(set(s2))))
# 9 [[x, l.count(x)] for x in set(l)]
# 10 df.astype(bool).sum(axis=1)
# ##Done###
#
# 46 44778
# How would you make a comma-separated string from a list?
# """,""".join(l)
# 3
#
# ##FastText###
# 1 len(s)
# 2 result = ((a for (a, b) in original), (b for (a, b) in original))
# 3 list(t)
# 4 len(my_list)
# 5 answer = str(round(answer, 2))
# 6 s.split(' ', 4)
# 7 len(max(words, key=len))
# 8 any(key.startswith('EMP$$') for key in dict1)
# 9 sum(1 << i for i, b in enumerate(x) if b)
# 10 [image for menuitem in list_of_menuitems for image in menuitem]
# ##SuperVised Starspace###
# 1 (n for n in [1, 2, 3, 5])
# 2 print(l[3:] + l[:3])
# 3 list(itertools.combinations((1, 2, 3), 2))
# 4 """,""".join(l)
# 5 print('\t'.join(map(str, list)))
# 6 [[x, l.count(x)] for x in set(l)]
# 7 matrix = [[a, b], [c, d], [e, f]]
# 8 print([item for item in [1, 2, 3]])
# 9 y = [[] for n in range(2)]
# 10 T2 = [map(int, x) for x in T1]
# ##UnsuperVised Starspace###
# 1 [[x, l.count(x)] for x in set(l)]
# 2 print(concatenate((a, b), axis=1))
# 3 print(concatenate((a, b), axis=0))
# 4 data.reshape(-1, j).mean(axis=1).reshape(data.shape[0], -1)
# 5 Counter(l)
# 6 dict(((x, l.count(x)) for x in set(l)))
# 7 print(l[3:] + l[:3])
# 8 [k for k, v in list(Counter(mylist).items()) if v > 1]
# 9 [i for i, j in enumerate(myList) if 'how' in j.lower() or 'what' in j.lower()]
# 10 [re.sub('(?<!\\d)\\.(?!\\d)', ' ', i) for i in s]
# ##Done###
#
# 50 4357787
# python reverse tokens in a string
# """.""".join(s.split('.')[::-1])
# 0
#
# ##FastText###
# 1 len(s)
# 2 s.split(' ', 4)
# 3 len(my_list)
# 4 list(t)
# 5 any(key.startswith('EMP$$') for key in dict1)
# 6 answer = str(round(answer, 2))
# 7 [int(s) for s in user.split(',')]
# 8 (type(o) is str)
# 9 int()
# 10 s.encode('iso-8859-15')
# ##SuperVised Starspace###
# 1 """.""".join(s.split('.')[::-1])
# 2 """""".join(s.rsplit(',', 1))
# 3 re.split('(\\W+)', s)
# 4 ip = re.findall('[0-9]+(?:\\.[0-9]+){3}', s)
# 5 sorted(list_of_strings, key=lambda s: s.split(',')[1])
# 6 re.findall('\\b(\\w+)d\\b', s)
# 7 re.findall('n(?<=[^n]n)n+(?=[^n])(?i)', s)
# 8 """ """.join(content.split(' ')[:-1])
# 9 s.split(' ', 4)
# 10 [int(s) for s in user.split(',')]
# ##UnsuperVised Starspace###
# 1 dict(((x, l.count(x)) for x in set(l)))
# 2 list(map(lambda x, y: x + y, word[:-1], word[1:]))
# 3 [[x, l.count(x)] for x in set(l)]
# 4 [(x + y) for x, y in zip(word, word[1:])]
# 5 re.split('(\\W+)', s)
# 6 print(l[3:] + l[:3])
# 7 [x.strip() for x in '2.MATCHES $$TEXT$$ STRING'.split('$$TEXT$$')]
# 8 sorted(list_of_strings, key=lambda s: s.split(',')[1])
# 9 len(max(words, key=len))
# 10 [''.join(str(d) for d in x) for x in L]
# ##Done###
#
# 52 21787496
# converting epoch time with milliseconds to datetime
# time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(1236472051807 / 1000.0))
# 7
#
# ##FastText###
# 1 my_dict.update({'third_key': 1})
# 2 data.update({'a': 1, })
# 3 soup.find_all('span', {'class': 'starGryB sp'})
# 4 matplotlib.rc('font', **{'sans-serif': 'Arial', 'family': 'sans-serif'})
# 5 df.replace({'\n': '<br>'}, regex=True)
# 6 df.replace({'\n': '<br>'}, regex=True)
# 7 pd.DataFrame({'email': sf.index, 'list': sf.values})
# 8 data.update(a=1)
# 9 time.strptime('30/03/09 16:31:32.123', '%d/%m/%y %H:%M:%S.%f')
# 10 sorted(li, key=lambda x: datetime.strptime(x[1], '%d/%m/%Y'), reverse=True)
# ##SuperVised Starspace###
# 1 datetime.datetime.strptime(string_date, '%Y-%m-%d %H:%M:%S.%f')
# 2 then = datetime.datetime.strptime(when, '%Y-%m-%d').date()
# 3 'first string is: %s, second one is: %s' % (str1, 'geo.tif')
# 4 time.strptime('30/03/09 16:31:32.123', '%d/%m/%y %H:%M:%S.%f')
# 5 datetime.datetime.now().strftime('%H:%M:%S.%f')
# 6 target.write('%r\n%r\n%r\n' % (line1, line2, line3))
# 7 datetime.datetime.now()
# 8 datetime.datetime.fromtimestamp(s).strftime('%Y-%m-%d %H:%M:%S.%f')
# 9 time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(1236472051807 / 1000.0))
# 10 time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(1347517370))
# ##UnsuperVised Starspace###
# 1 newlist = sorted(list_to_be_sorted, key=lambda k: k['name'])
# 2 dict([('Name', 'Joe'), ('Age', 22)])
# 3 d['mynewkey'] = 'mynewvalue'
# 4 df['date'].apply(lambda x: x.toordinal())
# 5 pd.merge(split_df, csv_df, on=['key'], suffixes=('_left', '_right'))
# 6 list(map(lambda x, y: x + y, word[:-1], word[1:]))
# 7 pd.DataFrame({'email': sf.index, 'list': sf.values})
# 8 map(None, *[('a', 1), ('b', 2), ('c', 3), ('d', 4), ('e',)])
# 9 newlist = sorted(l, key=itemgetter('name'), reverse=True)
# 10 df.replace({'\n': '<br>'}, regex=True)
# ##Done###
#
# 65 4741537
# Append elements of a set to a list in Python
# a.extend(b)
# 2
#
# ##FastText###
# 1 result = ((a for (a, b) in original), (b for (a, b) in original))
# 2 len(s)
# 3 level1 = map(list, level1)
# 4 result = ([a for (a, b) in original], [b for (a, b) in original])
# 5 list(t)
# 6 return HttpResponse(data, mimetype='application/json')
# 7 s.split(' ', 4)
# 8 answer = str(round(answer, 2))
# 9 [element for element in lst if isinstance(element, int)]
# 10 [image for menuitem in list_of_menuitems for image in menuitem]
# ##SuperVised Starspace###
# 1 (n for n in [1, 2, 3, 5])
# 2 result = ([a for (a, b) in original], [b for (a, b) in original])
# 3 a.extend(list(b))
# 4 result = ((a for (a, b) in original), (b for (a, b) in original))
# 5 a.extend(b)
# 6 q.put((-n, n))
# 7 b.append((a[0][0], a[0][2]))
# 8 y = [[] for n in range(2)]
# 9 list(set(t))
# 10 from functools import reduce
# reduce(lambda a, b: a + b, (('aa',), ('bb',), ('cc',)))
# ##UnsuperVised Starspace###
# 1 b.append((a[0][0], a[0][2]))
# 2 sys.path.append('/path/to/whatever')
# 3 my_list.append(12)
# 4 for line in mylog:
#     list1.append(line)
# 5 df.index.get_loc('bob')
# 6 zip(*[('a', 1), ('b', 2), ('c', 3), ('d', 4), ('e',)])
# 7 sys.path.append(os.path.join(os.path.dirname(__file__), 'subdir'))
# 8 map(None, *[('a', 1), ('b', 2), ('c', 3), ('d', 4), ('e',)])
# 9 l.count('b')
# 10 elements = ['%{0}%'.format(element) for element in elements]
# ##Done###
#
# 67 31247198
# Python, Pandas : write content of DataFrame into text File
# np.savetxt('c:\\data\\np.txt', df.values, fmt='%d')
# 5
#
# ##FastText###
# 1 len(s)
# 2 answer = str(round(answer, 2))
# 3 list(t)
# 4 s.encode('iso-8859-15')
# 5 len(my_list)
# 6 (type(o) is str)
# 7 any(key.startswith('EMP$$') for key in dict1)
# 8 return HttpResponse(data, mimetype='application/json')
# 9 s.split(' ', 4)
# 10 r = requests.get(url)
# ##SuperVised Starspace###
# 1 newFile.write(struct.pack('5B', *newFileBytes))
# 2 open('filename', 'wb').write(bytes_)
# 3 df.to_csv(filename, index=False)
# 4 arr = numpy.fromiter(codecs.open('new.txt', encoding='utf-8'), dtype='<U2')
# 5 open('outfile', 'w').write('#test firstline\n' + open('infile').read())
# 6 np.savetxt('c:\\data\\np.txt', df.values, fmt='%d')
# 7 df.to_csv('c:\\data\\pandas.txt', header=None, index=None, sep=' ', mode='a')
# 8 df.to_sql('test', engine, schema='a_schema')
# 9 pd.concat([df[0].apply(pd.Series), df[1]], axis=1)
# 10 df.xs('sat', level='day', drop_level=False)
# ##UnsuperVised Starspace###
# 1 with open('somefile.txt', 'a') as the_file:
#     the_file.write('Hello\n')
# 2 myfile.write('\n'.join(lines))
# 3 target.write('%r\n%r\n%r\n' % (line1, line2, line3))
# 4 sys.stdout.write('.')
# 5 df.loc[df['Letters'] == 'C', 'Letters'].values[0]
# 6 df.loc[df['BoolCol']]
# 7 [x for x in mylist if len(x) == 3]
# 8 u = urllib.request.urlopen(url)
# f = open(file_name, 'wb')
# meta = u.info()
# file_size = int(meta.getheaders('Content-Length')[0])
# print(('Downloading: %s Bytes: %s' % (file_name, file_size)))
# file_size_dl = 0
# block_sz = 8192
# while True:
#     buffer = u.read(block_sz)
#     if (not buffer):
#         break
#     file_size_dl += len(buffer)
#     f.write(buffer)
#     status = ('%10d  [%3.2f%%]' % (file_size_dl, ((file_size_dl * 100.0) / file_size)))
#     status = (status + (chr(8) * (len(status) + 1)))
#     print(status, end=' ')
# f.close()
# 9 newFile.write(struct.pack('5B', *newFileBytes))
# 10 open('outfile', 'w').write('#test firstline\n' + open('infile').read())
# ##Done###
#
# 71 17438096
# FTP upload files Python
# ftp.storlines('STOR ' + filename, open(filename, 'r'))
# 5
#
# ##FastText###
# 1 file = open('Output.txt', 'a')
# 2 f = open('yourfile.txt', 'w')
# 3 print('hi there', file=f)
# 4 new_file = open('path/to/FILE_NAME.ext', 'w')
# 5 r = requests.post(url, files=files, headers=headers, data=data)
# 6 requests.post(url, data=DATA, headers=HEADERS_DICT, auth=(username, password))
# 7 parser.add_argument('--version', action='version', version='%(prog)s 2.0')
# 8 arr = numpy.fromiter(codecs.open('new.txt', encoding='utf-8'), dtype='<U2')
# 9 df.to_sql('test', engine, schema='a_schema')
# 10 df.xs('sat', level='day', drop_level=False)
# ##SuperVised Starspace###
# 1 open(filename, 'w').close()
# 2 open('filename', 'wb').write(bytes_)
# 3 open('outfile', 'w').write('#test firstline\n' + open('infile').read())
# 4 file = open('Output.txt', 'a')
# 5 new_file = open('path/to/FILE_NAME.ext', 'w')
# 6 ftp.storlines('STOR ' + filename, open(filename, 'r'))
# 7 pickle.dump(mylist, open('save.txt', 'wb'))
# 8 open(path, 'r')
# 9 os.kill(os.getpid(), signal.SIGUSR1)
# 10 lol = list(csv.reader(open('text.txt', 'rb'), delimiter='\t'))
# ##UnsuperVised Starspace###
# 1 file.seek(0)
# 2 os.path.splitext(filename)[0]
# 3 [image for menuitem in list_of_menuitems for image in menuitem]
# 4 session.execute('INSERT INTO t1 (SELECT * FROM t2)')
# 5 for (root, dirs, files) in os.walk('/mydir'):
#     for file in files:
#         if file.endswith('.txt'):
#             pass
# 6 for (root, dirs, filenames) in os.walk(source):
#     for f in filenames:
#         pass
# 7 plt.colorbar(mappable=mappable, cax=ax3)
# 8 image = image.resize((x, y), Image.ANTIALIAS)
# 9 c.extend(a)
# 10 all(predicate(x) for x in string)
# ##Done###
#
# 74 34280147
# How to print an entire list while not starting by the first item
# print(l[3:] + l[:3])
# 0
#
# ##FastText###
# 1 result = ((a for (a, b) in original), (b for (a, b) in original))
# 2 [element for element in lst if isinstance(element, int)]
# 3 level1 = map(list, level1)
# 4 [element for element in lst if not isinstance(element, str)]
# 5 result = ([a for (a, b) in original], [b for (a, b) in original])
# 6 y = [[] for n in range(2)]
# 7 print([item for item in [1, 2, 3]])
# 8 (n for n in [1, 2, 3, 5])
# 9 [index for index, item in enumerate(thelist) if item[0] == '332']
# 10 {i: d[i] for i in d if i != 'c'}
# ##SuperVised Starspace###
# 1 print(l[3:] + l[:3])
# 2 """,""".join(l)
# 3 (n for n in [1, 2, 3, 5])
# 4 print([item for item in [1, 2, 3]])
# 5 y = [[] for n in range(2)]
# 6 [[x, l.count(x)] for x in set(l)]
# 7 list(itertools.combinations((1, 2, 3), 2))
# 8 len(l)
# 9 Counter(l)
# 10 np.maximum([2, 3, 4], [1, 5, 2])
# ##UnsuperVised Starspace###
# 1 elements = ['%{0}%'.format(element) for element in elements]
# 2 heapq.nlargest(10, range(len(l1)), key=lambda i: abs(l1[i] - l2[i]))
# 3 print([item for item in [1, 2, 3]])
# 4 plt.plot(x, y, label='H\u2082O')
# 5 plt.plot(x, y, label='$H_2O$')
# 6 [[x, l.count(x)] for x in set(l)]
# 7 max(lis, key=lambda item: item[1])[0]
# 8 list.sort(key=lambda item: (item['points'], item['time']))
# 9 """ """.join(content.split(' ')[:-1])
# 10 [x for x in mylist if len(x) == 3]
# ##Done###
#
# 75 11801309
# loop over files
# for fn in os.listdir('.'):
#     if os.path.isfile(fn):
#         pass
# 1
#
# ##FastText###
# 1 subprocess.Popen(['background-process', 'arguments'])
# 2 subprocess.call(['python.exe', 'hello.py', 'htmlfilename.htm'])
# 3 subprocess.call(['/usr/bin/Rscript', '--vanilla', '/pathto/MyrScript.r'])
# 4 request.args['myParam']
# 5 subprocess.call('/usr/bin/Rscript --vanilla /pathto/MyrScript.r', shell=True)
# 6 subprocess.call('sleep.sh', shell=True)
# 7 subprocess.check_output('ps -ef | grep something | wc -l', shell=True)
# 8 subprocess.check_call('vasp | tee tee_output', shell=True)
# 9 df.loc[df[0].str.contains('(Hel|Just)')]
# 10 df[df['ids'].str.contains('ball')]
# ##SuperVised Starspace###
# 1 os.chdir('/mydir')
# for file in glob.glob('*.txt'):
#     pass
# 2 for fn in os.listdir('.'):
#     if os.path.isfile(fn):
#         pass
# 3 for (root, dirs, files) in os.walk('/mydir'):
#     for file in files:
#         if file.endswith('.txt'):
#             pass
# 4 if (not os.path.exists(directory)):
#     os.makedirs(directory)
# 5 for file in os.listdir('/mydir'):
#     if file.endswith('.txt'):
#         pass
# 6 for (root, dirs, filenames) in os.walk(source):
#     for f in filenames:
#         pass
# 7 os.path.isabs(my_path)
# 8 os.chdir(owd)
# 9 os.kill(os.getpid(), signal.SIGUSR1)
# 10 try:
#     os.makedirs(path)
# except OSError:
#     if (not os.path.isdir(path)):
#         raise
# ##UnsuperVised Starspace###
# 1 if (not os.path.exists(directory)):
#     os.makedirs(directory)
# 2 df.replace({'\n': '<br>'}, regex=True)
# 3 df.replace({'\n': '<br>'}, regex=True)
# 4 result[0]['from_user']
# 5 np.array([zip(x, y) for x, y in zip(a, b)])
# 6 [x for x in myList if x.n == 30]
# 7 [[sum(item) for item in zip(*items)] for items in zip(*data)]
# 8 [[x, l.count(x)] for x in set(l)]
# 9 for (root, dirs, files) in os.walk('/mydir'):
#     for file in files:
#         if file.endswith('.txt'):
#             pass
# 10 """:""".join(str(x) for x in b)
# ##Done###
#
# 79 852055
# Build a GQL query (for Google App Engine) that has a condition on ReferenceProperty
# db.GqlQuery('SELECT * FROM Schedule WHERE station = $1', foo.key())
# 1
#
# ##FastText###
# 1 print(concatenate((a, b), axis=1))
# 2 lol = list(csv.reader(open('text.txt', 'rb'), delimiter='\t'))
# 3 sorted(list5, key=lambda vertex: (degree(vertex), vertex))
# 4 ax.set_xticklabels(labels, rotation=45)
# 5 image = image.resize((x, y), Image.ANTIALIAS)
# 6 df1.merge(df2, on='Date_Time')
# 7 len(max(words, key=len))
# 8 getattr(obj, 'attr')
# 9 getattr(my_object, my_str)
# 10 print(concatenate((a, b), axis=0))
# ##SuperVised Starspace###
# 1 db.execute("INSERT INTO present VALUES('test2', ?, 10)", (None,))
# 2 db.GqlQuery('SELECT * FROM Schedule WHERE station = $1', foo.key())
# 3 np.column_stack(([1, 2, 3], [4, 5, 6]))
# 4 np.where(np.in1d(A, [1, 3, 4]).reshape(A.shape), A, 0)
# 5 session.execute('INSERT INTO t1 (SELECT * FROM t2)')
# 6 Entry.objects.filter()[:1].get()
# 7 numpy.zeros((3, 3, 3))
# 8 c.execute("INSERT INTO test VALUES (?, 'bar')", (testfield,))
# 9 c = np.r_[(a[None, :], b[None, :])]
# 10 np.vstack((A, B))
# ##UnsuperVised Starspace###
# 1 session.execute('INSERT INTO t1 (SELECT * FROM t2)')
# 2 c.execute("INSERT INTO test VALUES (?, 'bar')", (testfield,))
# 3 df['c'] = np.where(df['a'].isnull, df['b'], df['a'])
# 4 """""".join(['a', 'b', 'c'])
# 5 data['weekday'] = data['my_dt'].apply(lambda x: x.weekday())
# 6 l.count('b')
# 7 zip(*[('a', 1), ('b', 2), ('c', 3), ('d', 4), ('e',)])
# 8 zip(*[('a', 1), ('b', 2), ('c', 3), ('d', 4)])
# 9 zip(*[('a', 1), ('b', 2), ('c', 3), ('d', 4)])
# 10 numpy.array(a)[0].tolist()
# ##Done###
#
# 84 13945749
# String Formatting in Python 3
# """({} goals, ${})""".format(self.goals, self.penalties)
# 1
#
# ##FastText###
# 1 result = ((a for (a, b) in original), (b for (a, b) in original))
# 2 data.update({'a': 1, })
# 3 res = {k: v for k, v in list(kwargs.items()) if v is not None}
# 4 return HttpResponse(data, mimetype='application/json')
# 5 print('%*s : %*s' % (20, 'Python', 20, 'Very Good'))
# 6 'first string is: %s, second one is: %s' % (str1, 'geo.tif')
# 7 my_dict.update({'third_key': 1})
# 8 res = dict((k, v) for k, v in kwargs.items() if v is not None)
# 9 soup.find_all('span', {'class': 'starGryB sp'})
# 10 s.split(' ', 4)
# ##SuperVised Starspace###
# 1 matplotlib.rc('font', **{'sans-serif': 'Arial', 'family': 'sans-serif'})
# 2 """({0.goals} goals, ${0.penalties})""".format(self)
# 3 dict([('Name', 'Joe'), ('Age', 22)])
# 4 print('"{}"'.format(word))
# 5 subprocess.Popen(['background-process', 'arguments'])
# 6 subprocess.call(['/usr/bin/Rscript', '--vanilla', '/pathto/MyrScript.r'])
# 7 subprocess.call(['python.exe', 'hello.py', 'htmlfilename.htm'])
# 8 """({} goals, ${})""".format(self.goals, self.penalties)
# 9 """({:d} goals, ${:d})""".format(self.goals, self.penalties)
# 10 print('{0:.0f}%'.format(1.0 / 3 * 100))
# ##UnsuperVised Starspace###
# 1 my_dict.update({'third_key': 1})
# 2 data.update({'a': 1, })
# 3 {i[1]: i[0] for i in list(myDictionary.items())}
# 4 {i: d[i] for i in d if i != 'c'}
# 5 my_dict.update((x, y * 2) for x, y in list(my_dict.items()))
# 6 [k for k, v in list(Counter(mylist).items()) if v > 1]
# 7 list(dict.keys())[-1]
# 8 max(k for k, v in x.items() if v != 0)
# 9 max(k for k, v in x.items() if v != 0)
# 10 print(l[3:] + l[:3])
# ##Done###
#
# 85 13945749
# String Formatting in Python 3
# """({0.goals} goals, ${0.penalties})""".format(self)
# 0
#
# ##FastText###
# 1 matplotlib.rc('font', **{'sans-serif': 'Arial', 'family': 'sans-serif'})
# 2 df.replace({'\n': '<br>'}, regex=True)
# 3 df.replace({'\n': '<br>'}, regex=True)
# 4 soup.find_all('span', {'class': 'starGryB sp'})
# 5 my_dict.update({'third_key': 1})
# 6 l = sorted(l, key=lambda a: a['time'], reverse=True)
# 7 requests.post(url, data=DATA, headers=HEADERS_DICT, auth=(username, password))
# 8 data.update({'a': 1, })
# 9 r = requests.post(url, files=files, headers=headers, data=data)
# 10 parser.add_argument('--version', action='version', version='%(prog)s 2.0')
# ##SuperVised Starspace###
# 1 """({0.goals} goals, ${0.penalties})""".format(self)
# 2 matplotlib.rc('font', **{'sans-serif': 'Arial', 'family': 'sans-serif'})
# 3 my_dict.update({'third_key': 1})
# 4 data.update({'a': 1, })
# 5 soup.find_all('span', {'class': 'starGryB sp'})
# 6 print('"{}"'.format(word))
# 7 df.replace({'\n': '<br>'}, regex=True)
# 8 df.replace({'\n': '<br>'}, regex=True)
# 9 """({} goals, ${})""".format(self.goals, self.penalties)
# 10 """({:d} goals, ${:d})""".format(self.goals, self.penalties)
# ##UnsuperVised Starspace###
# 1 my_dict.update({'third_key': 1})
# 2 {i[1]: i[0] for i in list(myDictionary.items())}
# 3 data.update({'a': 1, })
# 4 newlist = sorted(list_to_be_sorted, key=lambda k: k['name'])
# 5 {i: d[i] for i in d if i != 'c'}
# 6 isinstance(o, str)
# 7 isinstance(o, str)
# 8 """, """.join('(' + ', '.join(i) + ')' for i in L)
# 9 [k for k, v in list(Counter(mylist).items()) if v > 1]
# 10 pd.DataFrame({'email': sf.index, 'list': sf.values})
# ##Done###
#
# 93 15534223
# Python match string if it does not start with X
# re.search('(?<!Distillr)\\\\AcroTray\\.exe', 'C:\\SomeDir\\AcroTray.exe')
# 6
#
# ##FastText###
# 1 subprocess.call(['/usr/bin/Rscript', '--vanilla', '/pathto/MyrScript.r'])
# 2 subprocess.call(['python.exe', 'hello.py', 'htmlfilename.htm'])
# 3 re.sub('i', '', 'it is icy')
# 4 re.sub('\\D', '', 'aas30dsa20')
# 5 text = re.sub('\\b(\\w+)( \\1\\b)+', '\\1', text)
# 6 re.sub('[^A-Za-z0-9]+', '', mystring)
# 7 text = re.sub('^https?:\\/\\/.*[\\r\\n]*', '', text, flags=re.MULTILINE)
# 8 subprocess.Popen(['background-process', 'arguments'])
# 9 re.sub('^[A-Z0-9]*(?![a-z])', '', string)
# 10 subprocess.call('/usr/bin/Rscript --vanilla /pathto/MyrScript.r', shell=True)
# ##SuperVised Starspace###
# 1 print(re.search('>.*<', line).group(0))
# 2 re.findall('Test([\\d.]*\\d+)', text)
# 3 re.findall('(.+?):(.+?)\\b ?', text)
# 4 re.findall('Test([0-9.]*[0-9]+)', text)
# 5 re.findall('"(http.*?)"', s, re.MULTILINE | re.DOTALL)
# 6 print(re.search('(?P<url>https?://[^\\s]+)', myString).group('url'))
# 7 re.search('(?<!Distillr)\\\\AcroTray\\.exe', 'C:\\SomeDir\\AcroTray.exe')
# 8 re.search('\\[(.*)\\]', your_string).group(1)
# 9 [m.group(0) for m in re.finditer('(\\d)\\1*', s)]
# 10 re.findall('\\(.*?\\)|\\w', '(zyx)bc')
# ##UnsuperVised Starspace###
# 1 df.replace({'\n': '<br>'}, regex=True)
# 2 df.replace({'\n': '<br>'}, regex=True)
# 3 [x for x in myList if x.n == 30]
# 4 print('lamp, bag, mirror'.replace('bag,', ''))
# 5 float('123,456.908'.replace(',', ''))
# 6 list(map(lambda x, y: x + y, word[:-1], word[1:]))
# 7 print(x.rsplit('-', 1)[0])
# 8 [(x + y) for x, y in zip(word, word[1:])]
# 9 map(int, eval(input('Enter the unfriendly numbers: ')))
# 10 Entry.objects.filter()[:1].get()
# ##Done###
#
# 94 5453026
# String to list in Python
# """QH QD JC KD JS""".split()
# 2
#
# ##FastText###
# 1 l = sorted(l, key=lambda a: a['time'], reverse=True)
# 2 result = ([a for (a, b) in original], [b for (a, b) in original])
# 3 matrix = [[a, b], [c, d], [e, f]]
# 4 generator = iter_iprange('192.168.1.1', '192.168.255.255', step=1)
# 5 df['group'].plot(kind='bar', color=['r', 'g', 'b', 'r', 'g', 'b', 'r'])
# 6 values = sum([['A', 'B', 'C'], ['D', 'E', 'F'], ['G', 'H', 'I']], [])
# 7 df.to_csv('c:\\data\\pandas.txt', header=None, index=None, sep=' ', mode='a')
# 8 my_list = []
# 9 """""".join(['A', 'B', 'C', 'D'])
# 10 list(map(lambda x, y: x + y, word[:-1], word[1:]))
# ##SuperVised Starspace###
# 1 re.split('[ ](?=[A-Z])', input)
# 2 re.split('[ ](?=[A-Z]+\\b)', input)
# 3 """QH QD JC KD JS""".split()
# 4 """ """.join(my_string.split())
# 5 re.split('(\\W+)', 'Words, words, words.')
# 6 re.split(' +', 'hello world sample text')
# 7 re.split('(\\W+)', s)
# 8 inputString.split('\n')
# 9 ' a \n b \r\n c '.split('\n')
# 10 [x.strip() for x in '2.MATCHES $$TEXT$$ STRING'.split('$$TEXT$$')]
# ##UnsuperVised Starspace###
# 1 print(s.encode('unicode-escape').replace('"', '\\"'))
# 2 df.replace({'\n': '<br>'}, regex=True)
# 3 df.replace({'\n': '<br>'}, regex=True)
# 4 print('lamp, bag, mirror'.replace('bag,', ''))
# 5 float('123,456.908'.replace(',', ''))
# 6 mystring.replace(' ', '_')
# 7 my_float = float(my_string.replace(',', ''))
# 8 df1.merge(df2, on='Date_Time')
# 9 result[0]['from_user']
# 10 re.split(' +', 'hello world sample text')
# ##Done###
#
# 95 18168684
# Parsing XML in Python with regex
# print(re.search('>.*<', line).group(0))
# 7
#
# ##FastText###
# 1 for line in mylog:
#     list1.append(line)
# 2 [m.group(0) for m in re.finditer('(\\d)\\1*', s)]
# 3 [line.split() for line in open('File.txt')]
# 4 re.findall('src="js/([^"]*\\bjquery\\b[^"]*)"', data)
# 5 re.findall('([a-fA-F\\d]{32})', data)
# 6 [line.rstrip('\n') for line in file]
# 7 """, """.join('(' + ', '.join(i) + ')' for i in L)
# 8 re.findall('http://[^t][^s"]+\\.html', document)
# 9 re.findall('n(?<=[^n]n)n+(?=[^n])(?i)', s)
# 10 re.findall('\\b(\\w+)d\\b', s)
# ##SuperVised Starspace###
# 1 re.search('(?<!Distillr)\\\\AcroTray\\.exe', 'C:\\SomeDir\\AcroTray.exe')
# 2 re.findall('\\(.*?\\)|\\w', '(zyx)bc')
# 3 re.findall('(.*?)\\[.*?\\]', example_str)
# 4 re.findall('(.*?)(?:\\[.*?\\]|$)', example_str)
# 5 re.findall('\\(.+?\\)|\\w', '(zyx)bc')
# 6 re.findall('\\((.*?)\\)|(\\w)', '(zyx)bc')
# 7 re.findall('http://[^t][^s"]+\\.html', document)
# 8 print(re.search('>.*<', line).group(0))
# 9 bool(re.search('ba[rzd]', 'foobarrrr'))
# 10 re.search('\\[(.*)\\]', your_string).group(1)
# ##UnsuperVised Starspace###
# 1 df.replace({'\n': '<br>'}, regex=True)
# 2 df.replace({'\n': '<br>'}, regex=True)
# 3 re.sub('[^\\sa-zA-Z0-9]', '', text).lower().strip()
# 4 re.sub('(?!\\s)[\\W_]', '', text).lower().strip()
# 5 a[np.where((a[:, (0)] == 0) * (a[:, (1)] == 1))]
# 6 [i for i, j in enumerate(myList) if 'how' in j.lower() or 'what' in j.lower()]
# 7 [x for x in mylist if len(x) == 3]
# 8 list.sort(key=lambda item: (item['points'], item['time']))
# 9 df.groupby('A').filter(lambda x: len(x) > 1)
# 10 [i for i in teststr if re.search('\\d+[xX]', i)]
# ##Done###
#
# 96 4914277
# How to empty a file using Python
# open(filename, 'w').close()
# 0
#
# ##FastText###
# 1 open(path, 'r')
# 2 len(s)
# 3 list(t)
# 4 len(my_list)
# 5 for line in mylog:
#     list1.append(line)
# 6 for file in os.listdir('/mydir'):
#     if file.endswith('.txt'):
#         pass
# 7 for (root, dirs, files) in os.walk('/mydir'):
#     for file in files:
#         if file.endswith('.txt'):
#             pass
# 8 for fn in os.listdir('.'):
#     if os.path.isfile(fn):
#         pass
# 9 len(max(words, key=len))
# 10 answer = str(round(answer, 2))
# ##SuperVised Starspace###
# 1 open(filename, 'w').close()
# 2 ftp.storlines('STOR ' + filename, open(filename, 'r'))
# 3 open('outfile', 'w').write('#test firstline\n' + open('infile').read())
# 4 file = open('Output.txt', 'a')
# 5 open(path, 'r')
# 6 open('filename', 'wb').write(bytes_)
# 7 new_file = open('path/to/FILE_NAME.ext', 'w')
# 8 pickle.dump(mylist, open('save.txt', 'wb'))
# 9 f = open('yourfile.txt', 'w')
# 10 with open('somefile.txt', 'a') as the_file:
#     the_file.write('Hello\n')
# ##UnsuperVised Starspace###
# 1 os.path.splitext(filename)[0]
# 2 print(soup.find(text='Address:').findNext('td').contents[0])
# 3 ftp.storlines('STOR ' + filename, open(filename, 'r'))
# 4 [[x, l.count(x)] for x in set(l)]
# 5 l.count('a')
# 6 dict(((x, l.count(x)) for x in set(l)))
# 7 print('hi there', file=f)
# 8 l.count('b')
# 9 y = [[] for n in range(2)]
# 10 df.to_csv(filename, index=False)
# ##Done###
#
# 97 19068269
# how to convert a string date into datetime format in python?
# datetime.datetime.strptime(string_date, '%Y-%m-%d %H:%M:%S.%f')
# 0
#
# ##FastText###
# 1 my_dict.update({'third_key': 1})
# 2 data.update({'a': 1, })
# 3 soup.find_all('span', {'class': 'starGryB sp'})
# 4 data.update(a=1)
# 5 df.replace({'\n': '<br>'}, regex=True)
# 6 df.replace({'\n': '<br>'}, regex=True)
# 7 matplotlib.rc('font', **{'sans-serif': 'Arial', 'family': 'sans-serif'})
# 8 print('%*s : %*s' % (20, 'Python', 20, 'Very Good'))
# 9 pd.DataFrame({'email': sf.index, 'list': sf.values})
# 10 time.strptime('30/03/09 16:31:32.123', '%d/%m/%y %H:%M:%S.%f')
# ##SuperVised Starspace###
# 1 datetime.datetime.strptime(string_date, '%Y-%m-%d %H:%M:%S.%f')
# 2 then = datetime.datetime.strptime(when, '%Y-%m-%d').date()
# 3 'first string is: %s, second one is: %s' % (str1, 'geo.tif')
# 4 target.write('%r\n%r\n%r\n' % (line1, line2, line3))
# 5 time.strptime('30/03/09 16:31:32.123', '%d/%m/%y %H:%M:%S.%f')
# 6 datetime.datetime.now().strftime('%H:%M:%S.%f')
# 7 datetime.datetime.fromtimestamp(s).strftime('%Y-%m-%d %H:%M:%S.%f')
# 8 datetime.datetime.now()
# 9 time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(1236472051807 / 1000.0))
# 10 time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(1347517370))
# ##UnsuperVised Starspace###
# 1 print('hi there', file=f)
# 2 newlist = sorted(list_to_be_sorted, key=lambda k: k['name'])
# 3 d['mynewkey'] = 'mynewvalue'
# 4 df.loc[df['Letters'] == 'C', 'Letters'].values[0]
# 5 df['A'][(df['B'] > 50) & (df['C'] == 900)]
# 6 list(data['A']['B'].values())[0]['maindata'][0]['Info']
# 7 data.update({'a': 1, })
# 8 dict([('Name', 'Joe'), ('Age', 22)])
# 9 df['date'].apply(lambda x: x.toordinal())
# 10 a[np.where((a[:, (0)] == 0) * (a[:, (1)] == 1))]
# ##Done###
#
# 108 3367288
# insert variable values into a string in python
# 'first string is: %s, second one is: %s' % (str1, 'geo.tif')
# 4
#
# ##FastText###
# 1 len(s)
# 2 s.split(' ', 4)
# 3 s.encode('iso-8859-15')
# 4 (type(o) is str)
# 5 list(t)
# 6 any(key.startswith('EMP$$') for key in dict1)
# 7 int()
# 8 int('1')
# 9 answer = str(round(answer, 2))
# 10 len(my_list)
# ##SuperVised Starspace###
# 1 """""".join(s.rsplit(',', 1))
# 2 """,""".join(l)
# 3 print('\t'.join(map(str, list)))
# 4 print(' '.join(map(str, l)))
# 5 'first string is: %s, second one is: %s' % (str1, 'geo.tif')
# 6 print(l[3:] + l[:3])
# 7 answer = str(round(answer, 2))
# 8 [int(s) for s in user.split(',')]
# 9 s.split(' ', 4)
# 10 print('%*s : %*s' % (20, 'Python', 20, 'Very Good'))
# ##UnsuperVised Starspace###
# 1 list_of_dicts.sort(key=operator.itemgetter('age'))
# 2 list_of_dicts.sort(key=operator.itemgetter('name'))
# 3 data.reshape(-1, j).mean(axis=1).reshape(data.shape[0], -1)
# 4 max(lis, key=itemgetter(1))[0]
# 5 np.where(np.in1d(A, [1, 3, 4]).reshape(A.shape), A, 0)
# 6 np.array(zip(a.ravel(), b.ravel()), dtype='i4,i4').reshape(a.shape)
# 7 l = sorted(l, key=itemgetter('time'), reverse=True)
# 8 sorted(list(x.items()), key=lambda pair: pair[1], reverse=True)
# 9 newlist = sorted(l, key=itemgetter('name'), reverse=True)
# 10 next(i for i, x in enumerate(lst) if not isinstance(x, bool) and x == 1)
# ##Done###
#
# 109 3475251
# Split a string by a delimiter in python
# [x.strip() for x in '2.MATCHES $$TEXT$$ STRING'.split('$$TEXT$$')]
# 6
#
# ##FastText###
# 1 result = ((a for (a, b) in original), (b for (a, b) in original))
# 2 result = ([a for (a, b) in original], [b for (a, b) in original])
# 3 sorted(list_of_strings, key=lambda s: s.split(',')[1])
# 4 sum(int(float(item)) for item in [_f for _f in ['', '3.4', '', '', '1.0'] if _f])
# 5 a[:] = [(x - 13) for x in a]
# 6 l = sorted(l, key=lambda a: a['time'], reverse=True)
# 7 data.update(a=1)
# 8 [element for element in lst if isinstance(element, int)]
# 9 l = sorted(l, key=itemgetter('time'), reverse=True)
# 10 brackets = re.sub('[^(){}[\\]]', '', s)
# ##SuperVised Starspace###
# 1 """ """.join(content.split(' ')[:-1])
# 2 ip = re.findall('[0-9]+(?:\\.[0-9]+){3}', s)
# 3 """.""".join(s.split('.')[::-1])
# 4 re.split('(\\W+)', s)
# 5 re.findall('n(?<=[^n]n)n+(?=[^n])(?i)', s)
# 6 re.findall('\\b(\\w+)d\\b', s)
# 7 [x.strip() for x in '2.MATCHES $$TEXT$$ STRING'.split('$$TEXT$$')]
# 8 """""".join(s.rsplit(',', 1))
# 9 brackets = re.sub('[^(){}[\\]]', '', s)
# 10 Counter(' '.join(df['text']).split()).most_common(100)
# ##UnsuperVised Starspace###
# 1 text.split(',')
# 2 [(x['x'], x['y']) for x in d]
# 3 sorted(list_of_strings, key=lambda s: s.split(',')[1])
# 4 user_list = [int(number) for number in user_input.split(',')]
# 5 s.split(' ', 4)
# 6 sorted(list(x.items()), key=lambda pair: pair[1], reverse=True)
# 7 text.split()
# 8 dict(((x, l.count(x)) for x in set(l)))
# 9 [mydict[x] for x in mykeys]
# 10 values = sum([['A', 'B', 'C'], ['D', 'E', 'F'], ['G', 'H', 'I']], [])
# ##Done###
#
# 114 18785032
# Replace a substring when it is a separate word
# re.sub('\\bH3\\b', 'H1', text)
# 8
#
# ##FastText###
# 1 """""".join(['A', 'B', 'C', 'D'])
# 2 text = re.sub('^https?:\\/\\/.*[\\r\\n]*', '', text, flags=re.MULTILINE)
# 3 df['range'].replace(',', '-', inplace=True)
# 4 matrix = [[a, b], [c, d], [e, f]]
# 5 values = sum([['A', 'B', 'C'], ['D', 'E', 'F'], ['G', 'H', 'I']], [])
# 6 df['group'].plot(kind='bar', color=['r', 'g', 'b', 'r', 'g', 'b', 'r'])
# 7 scipy.tensordot(P, T, axes=[1, 1]).swapaxes(0, 1)
# 8 a[:, (np.newaxis)]
# 9 c = np.r_[(a[None, :], b[None, :])]
# 10 parser.add_argument('--version', action='version', version='%(prog)s 2.0')
# ##SuperVised Starspace###
# 1 re.sub('(\\_a)?\\.([^\\.]*)$', '_suff.\\2', 'long.file.name.jpg')
# 2 re.sub('[^A-Za-z0-9]+', '', mystring)
# 3 brackets = re.sub('[^(){}[\\]]', '', s)
# 4 [word for word in mystring.split() if word.startswith('$')]
# 5 re.search('(?<!Distillr)\\\\AcroTray\\.exe', 'C:\\SomeDir\\AcroTray.exe')
# 6 re.sub('i', '', 'it is icy')
# 7 re.sub('\\D', '', 'aas30dsa20')
# 8 [re.sub('(?<!\\d)\\.(?!\\d)', ' ', i) for i in s]
# 9 re.sub('\\bH3\\b', 'H1', text)
# 10 ip = re.findall('[0-9]+(?:\\.[0-9]+){3}', s)
# ##UnsuperVised Starspace###
# 1 float('123,456.908'.replace(',', ''))
# 2 print('lamp, bag, mirror'.replace('bag,', ''))
# 3 df.replace({'\n': '<br>'}, regex=True)
# 4 df.replace({'\n': '<br>'}, regex=True)
# 5 print(s.encode('unicode-escape').replace('"', '\\"'))
# 6 [(x + y) for x, y in zip(word, word[1:])]
# 7 sum(1 << i for i, b in enumerate(x) if b)
# 8 df['range'].replace(',', '-', inplace=True)
# 9 list(map(lambda x, y: x + y, word[:-1], word[1:]))
# 10 [i for (i, x) in enumerate(testlist) if (x == 1)]
# ##Done###
#
# 116 1450897
# Python: removing characters except digits from string
# """""".join([x for x in 'aas30dsa20' if x.isdigit()])
# 0
#
# ##FastText###
# 1 len(s)
# 2 list(t)
# 3 s.split(' ', 4)
# 4 any(key.startswith('EMP$$') for key in dict1)
# 5 len(my_list)
# 6 (type(o) is str)
# 7 [int(s) for s in user.split(',')]
# 8 """ """.join(list)
# 9 list(set(t))
# 10 s.encode('iso-8859-15')
# ##SuperVised Starspace###
# 1 """""".join([x for x in 'aas30dsa20' if x.isdigit()])
# 2 print(re.findall("'\\\\[0-7]{1,3}'", str))
# 3 str(int(x) + 1).zfill(len(x))
# 4 """ """.join(my_string.split())
# 5 print(socket.getaddrinfo('google.com', 80))
# 6 """ """.join(content.split(' ')[:-1])
# 7 print(re.search('(?P<url>https?://[^\\s]+)', myString).group('url'))
# 8 c.extend(a)
# 9 print(re.findall('(https?://[^\\s]+)', myString))
# 10 """\\xF3\\xBE\\x80\\x80""".replace('\\x', '').decode('hex')
# ##UnsuperVised Starspace###
# 1 heapq.nlargest(10, range(len(l1)), key=lambda i: abs(l1[i] - l2[i]))
# 2 b.sort(key=lambda x: x[1][2])
# 3 sorted(list, key=lambda x: (x[0], -x[1]))
# 4 print(l[3:] + l[:3])
# 5 a[:] = [(x - 13) for x in a]
# 6 [x[::-1] for x in b]
# 7 str(int(x) + 1).zfill(len(x))
# 8 sorted(list5, lambda x: (degree(x), x))
# 9 x[:-1] + (x[1:] - x[:-1]) / 2
# 10 [element for element in lst if not isinstance(element, str)]
# ##Done###
#
# 131 17021863
# Re-read an open file Python
# file.seek(0)
# 7
#
# ##FastText###
# 1 file = open('Output.txt', 'a')
# 2 print('hi there', file=f)
# 3 f = open('yourfile.txt', 'w')
# 4 new_file = open('path/to/FILE_NAME.ext', 'w')
# 5 open(path, 'r')
# 6 for (root, dirs, files) in os.walk('/mydir'):
#     for file in files:
#         if file.endswith('.txt'):
#             pass
# 7 for (root, dirs, filenames) in os.walk(source):
#     for f in filenames:
#         pass
# 8 arr = numpy.fromiter(codecs.open('new.txt', encoding='utf-8'), dtype='<U2')
# 9 ftp.storlines('STOR ' + filename, open(filename, 'r'))
# 10 df.to_csv(filename, index=False)
# ##SuperVised Starspace###
# 1 os.stat(filepath).st_size
# 2 os.path.isabs(my_path)
# 3 os.path.abspath('mydir/myfile.txt')
# 4 os.path.basename(os.path.dirname(os.path.realpath(__file__)))
# 5 distutils.dir_util.mkpath(path)
# 6 print(os.path.splitext(os.path.basename('hemanth.txt'))[0])
# 7 open(filename, 'w').close()
# 8 file.seek(0)
# 9 os.path.splitext(filename)[0]
# 10 if (not os.path.exists(directory)):
#     os.makedirs(directory)
# ##UnsuperVised Starspace###
# 1 elements = ['%{0}%'.format(element) for element in elements]
# 2 (n for n in [1, 2, 3, 5])
# 3 l.count('b')
# 4 print(testlist.index(element))
# 5 re.sub('(?!\\s)[\\W_]', '', text).lower().strip()
# 6 re.sub('[^\\sa-zA-Z0-9]', '', text).lower().strip()
# 7 sys.path.append(os.path.join(os.path.dirname(__file__), 'subdir'))
# 8 [x for x in myList if x.n == 30]
# 9 """""".join(['a', 'b', 'c'])
# 10 l.count('a')
# ##Done###
#
# 133 4175686
# python: Is this a wrong way to remove an element from a dict?
# del d['ele']
# 0
#
# ##FastText###
# 1 any(key.startswith('EMP$$') for key in dict1)
# 2 sorted(d)
# 3 list(t)
# 4 for line in mylog:
#     list1.append(line)
# 5 print(sum(row[column] for row in data))
# 6 [image for menuitem in list_of_menuitems for image in menuitem]
# 7 [value for key, value in list(dict1.items()) if key.startswith('EMP$$')]
# 8 sorted(d.items())
# 9 [[sum(item) for item in zip(*items)] for items in zip(*data)]
# 10 len(my_list)
# ##SuperVised Starspace###
# 1 del d['ele']
# 2 d['mynewkey'] = 'mynewvalue'
# 3 dict((k, [d[k] for d in dicts]) for k in dicts[0])
# 4 {k: [d[k] for d in dicts] for k in dicts[0]}
# 5 [value for key, value in list(dict1.items()) if key.startswith('EMP$$')]
# 6 sorted(d.items())
# 7 d = ast.literal_eval("{'code1':1,'code2':1}")
# ...
# df.to_csv(filename, index=False)
# 0
#
# ##FastText###
# 1 r = requests.post(url, files=files, headers=headers, data=data)
# 2 df.to_csv('c:\\data\\pandas.txt', header=None, index=None, sep=' ', mode='a')
# 3 b = models.CharField(max_length=7, default='0000000', editable=False)
# 4 generator = iter_iprange('192.168.1.1', '192.168.255.255', step=1)
# 5 requests.post(url, data=DATA, headers=HEADERS_DICT, auth=(username, password))
# 6 df.xs('sat', level='day', drop_level=False)
# 7 df['group'].plot(kind='bar', color=['r', 'g', 'b', 'r', 'g', 'b', 'r'])
# 8 l = sorted(l, key=lambda a: a['time'], reverse=True)
# 9 parser.add_argument('--version', action='version', version='%(prog)s 2.0')
# 10 result = ([a for (a, b) in original], [b for (a, b) in original])
# ##SuperVised Starspace###
# 1 df.to_csv(filename, index=False)
# 2 df.to_csv('c:\\data\\pandas.txt', header=None, index=None, sep=' ', mode='a')
# 3 df.xs('sat', level='day', drop_level=False)
# 4 df.to_sql('test', engine, schema='a_schema')
# 5 pd.DataFrame(out.tolist(), columns=['out-1', 'out-2'], index=out.index)
# 6 open('filename', 'wb').write(bytes_)
# 7 newFile.write(struct.pack('5B', *newFileBytes))
# 8 arr = numpy.fromiter(codecs.open('new.txt', encoding='utf-8'), dtype='<U2')
# 9 np.savetxt('c:\\data\\np.txt', df.values, fmt='%d')
# 10 lol = list(csv.reader(open('text.txt', 'rb'), delimiter='\t'))
# ##UnsuperVised Starspace###
# 1 target.write('%r\n%r\n%r\n' % (line1, line2, line3))
# 2 with open('somefile.txt', 'a') as the_file:
#     the_file.write('Hello\n')
# 3 open('outfile', 'w').write('#test firstline\n' + open('infile').read())
# 4 newFile.write(struct.pack('5B', *newFileBytes))
# 5 element.get_attribute('innerHTML')
# 6 myfile.write('\n'.join(lines))
# 7 [index for index, item in enumerate(thelist) if item[0] == '332']
# 8 df['index1'] = df.index
# 9 df['c'] = np.where(df['a'].isnull, df['b'], df['a'])
# 10 f = open('myfile', 'w')
# f.write('hi there\n')
# f.close()
# ##Done###
#
# 477 21805490
# Python Regex - checking for a capital letter with a lowercase after
# re.sub('^[A-Z0-9]*(?![a-z])', '', string)
# 6
#
# ##FastText###
# 1 result = ((a for (a, b) in original), (b for (a, b) in original))
# 2 """""".join([char for char in 'it is icy' if char != 'i'])
# 3 """""".join([char for char in 'it is icy' if char != 'i'])
# 4 s.split(' ', 4)
# 5 [int(s) for s in user.split(',')]
# 6 for i in range(256):
#     for j in range(256):
#         ip = ('192.168.%d.%d' % (i, j))
#         print(ip)
# 7 [element for element in lst if not isinstance(element, str)]
# 8 [image for menuitem in list_of_menuitems for image in menuitem]
# 9 re.split('(\\W+)', s)
# 10 sorted(list_of_strings, key=lambda s: s.split(',')[1])
# ##SuperVised Starspace###
# 1 re.findall('(.*?)(?:\\[.*?\\]|$)', example_str)
# 2 re.findall('\\(.*?\\)|\\w', '(zyx)bc')
# 3 re.findall('http://[^t][^s"]+\\.html', document)
# 4 re.findall('(.*?)\\[.*?\\]', example_str)
# 5 re.findall('\\((.*?)\\)|(\\w)', '(zyx)bc')
# 6 re.findall('\\(.+?\\)|\\w', '(zyx)bc')
# 7 re.sub('^[A-Z0-9]*(?![a-z])', '', string)
# 8 re.search('(?<!Distillr)\\\\AcroTray\\.exe', 'C:\\SomeDir\\AcroTray.exe')
# 9 re.sub('(\\_a)?\\.([^\\.]*)$', '_suff.\\2', 'long.file.name.jpg')
# 10 re.findall('\\b(\\w+)d\\b', s)
# ##UnsuperVised Starspace###
# 1 numpy.array(a).reshape(-1).tolist()
# 2 list(dict.keys())[-1]
# 3 next(i for i, x in enumerate(lst) if not isinstance(x, bool) and x == 1)
# 4 my_dict.update((x, y * 2) for x, y in list(my_dict.items()))
# 5 data.reshape(-1, j).mean(axis=1).reshape(data.shape[0], -1)
# 6 dict(((x, l.count(x)) for x in set(l)))
# 7 x = np.asarray(x).reshape(1, -1)[(0), :]
# 8 [''.join(str(d) for d in x) for x in L]
# 9 list(dict((x[0], x) for x in L).values())
# 10 [element for element in lst if not isinstance(element, str)]
# ##Done###
#
# 484 356483
# Python regex findall numbers and dots
# re.findall('Test([0-9.]*[0-9]+)', text)
# 1
#
# ##FastText###
# 1 s.split(' ', 4)
# 2 len(s)
# 3 ip = re.findall('[0-9]+(?:\\.[0-9]+){3}', s)
# 4 re.findall('n(?<=[^n]n)n+(?=[^n])(?i)', s)
# 5 re.findall('\\b(\\w+)d\\b', s)
# 6 re.split('(\\W+)', s)
# 7 [int(s) for s in user.split(',')]
# 8 re.findall('"(http.*?)"', s, re.MULTILINE | re.DOTALL)
# 9 re.findall('([a-fA-F\\d]{32})', data)
# 10 re.findall('src="js/([^"]*\\bjquery\\b[^"]*)"', data)
# ##SuperVised Starspace###
# 1 re.findall('(.+?):(.+?)\\b ?', text)
# 2 re.findall('Test([0-9.]*[0-9]+)', text)
# 3 re.findall('Test([\\d.]*\\d+)', text)
# 4 re.findall('\\((.*?)\\)|(\\w)', '(zyx)bc')
# 5 re.findall('(.*?)\\[.*?\\]', example_str)
# 6 re.findall('(.*?)(?:\\[.*?\\]|$)', example_str)
# 7 re.findall('http://[^t][^s"]+\\.html', document)
# 8 re.findall('\\(.+?\\)|\\w', '(zyx)bc')
# 9 re.findall('\\(.*?\\)|\\w', '(zyx)bc')
# 10 re.sub('\\bH3\\b', 'H1', text)
# ##UnsuperVised Starspace###
# 1 max(x.min(), x.max(), key=abs)
# 2 heapq.nlargest(10, range(len(l1)), key=lambda i: abs(l1[i] - l2[i]))
# 3 max(k for k, v in x.items() if v != 0)
# 4 max(k for k, v in x.items() if v != 0)
# 5 len(max(words, key=len))
# 6 plt.plot(x, y, label='$H_2O$')
# 7 plt.plot(x, y, label='H\u2082O')
# 8 np.mean(a, axis=1)
# 9 max([max(i) for i in matrix])
# 10 list2 = [x for x in list1 if x != []]
# ##Done###
#
# 485 356483
# Python regex findall numbers and dots
# re.findall('Test([\\d.]*\\d+)', text)
# 9
#
# ##FastText###
# 1 text = re.sub('\\b(\\w+)( \\1\\b)+', '\\1', text)
# 2 text = re.sub('^https?:\\/\\/.*[\\r\\n]*', '', text, flags=re.MULTILINE)
# 3 brackets = re.sub('[^(){}[\\]]', '', s)
# 4 re.sub('i', '', 'it is icy')
# 5 re.sub('\\D', '', 'aas30dsa20')
# 6 re.sub('[^A-Za-z0-9]+', '', mystring)
# 7 re.sub('\\bH3\\b', 'H1', text)
# 8 re.sub('^[A-Z0-9]*(?![a-z])', '', string)
# 9 re.sub('(\\_a)?\\.([^\\.]*)$', '_suff.\\2', 'long.file.name.jpg')
# 10 re.sub('[^\\w]', ' ', s)
# ##SuperVised Starspace###
# 1 re.findall('src="js/([^"]*\\bjquery\\b[^"]*)"', data)
# 2 re.findall('([a-fA-F\\d]{32})', data)
# 3 re.findall('\\(.+?\\)|\\w', '(zyx)bc')
# 4 re.findall('(.*?)(?:\\[.*?\\]|$)', example_str)
# 5 re.findall('\\((.*?)\\)|(\\w)', '(zyx)bc')
# 6 re.findall('http://[^t][^s"]+\\.html', document)
# 7 re.findall('\\(.*?\\)|\\w', '(zyx)bc')
# 8 re.findall('(.*?)\\[.*?\\]', example_str)
# 9 re.sub('(\\_a)?\\.([^\\.]*)$', '_suff.\\2', 'long.file.name.jpg')
# 10 re.findall('Test([0-9.]*[0-9]+)', text)
# ##UnsuperVised Starspace###
# 1 newlist = sorted(l, key=itemgetter('name'), reverse=True)
# 2 max(x.min(), x.max(), key=abs)
# 3 max(lis, key=itemgetter(1))[0]
# 4 len(max(words, key=len))
# 5 max([max(i) for i in matrix])
# 6 max(lis, key=lambda item: item[1])[0]
# 7 dict(((x, l.count(x)) for x in set(l)))
# 8 list2 = [x for x in list1 if x != []]
# 9 list2 = [x for x in list1 if x]
# 10 sorted(x, key=x.get, reverse=True)
# ##Done###
#
# 486 38081866
# Is there a way to run powershell code in python
# os.system('powershell.exe', 'script.ps1')
# 8
#
# ##FastText###
# 1 df.to_sql('test', engine, schema='a_schema')
# 2 parser.add_argument('--version', action='version', version='%(prog)s 2.0')
# 3 df.replace({'\n': '<br>'}, regex=True)
# 4 df.replace({'\n': '<br>'}, regex=True)
# 5 requests.post(url, data=DATA, headers=HEADERS_DICT, auth=(username, password))
# 6 matplotlib.rc('font', **{'sans-serif': 'Arial', 'family': 'sans-serif'})
# 7 df['group'].plot(kind='bar', color=['r', 'g', 'b', 'r', 'g', 'b', 'r'])
# 8 soup.find_all('span', {'class': 'starGryB sp'})
# 9 df.xs('sat', level='day', drop_level=False)
# 10 df.plot(kind='barh', stacked=True)
# ##SuperVised Starspace###
# 1 subprocess.call(['notepad'])
# 2 subprocess.call(['./test.sh'])
# 3 subprocess.call('sleep.sh', shell=True)
# 4 subprocess.call('/usr/bin/Rscript --vanilla /pathto/MyrScript.r', shell=True)
# 5 os.system('gnome-terminal -e \'bash -c "sudo apt-get update; exec bash"\'')
# 6 subprocess.call(['python.exe', 'hello.py', 'htmlfilename.htm'])
# 7 subprocess.call(['/usr/bin/Rscript', '--vanilla', '/pathto/MyrScript.r'])
# 8 subprocess.check_output('ps -ef | grep something | wc -l', shell=True)
# 9 os.system('powershell.exe', 'script.ps1')
# 10 subprocess.check_call('vasp | tee tee_output', shell=True)
# ##UnsuperVised Starspace###
# 1 c.execute("INSERT INTO test VALUES (?, 'bar')", (testfield,))
# 2 subprocess.call('sleep.sh', shell=True)
# 3 subprocess.call('/usr/bin/Rscript --vanilla /pathto/MyrScript.r', shell=True)
# 4 subprocess.check_call('vasp | tee tee_output', shell=True)
# 5 subprocess.check_output('ps -ef | grep something | wc -l', shell=True)
# 6 session.execute('INSERT INTO t1 (SELECT * FROM t2)')
# 7 db.execute("INSERT INTO present VALUES('test2', ?, 10)", (None,))
# 8 shutil.rmtree('/folder_name')
# 9 df.replace({'\n': '<br>'}, regex=True)
# 10 df.replace({'\n': '<br>'}, regex=True)
# ##Done###
#
# 487 7349646
# Sorting a dictionary of tuples in Python
# b.sort(key=lambda x: x[1][2])
# 0
#
# ##FastText###
# 1 [image for menuitem in list_of_menuitems for image in menuitem]
# 2 list(t)
# 3 any(key.startswith('EMP$$') for key in dict1)
# 4 sum(1 << i for i, b in enumerate(x) if b)
# 5 [[sum(item) for item in zip(*items)] for items in zip(*data)]
# 6 sum(sum(i) if isinstance(i, list) else i for i in L)
# 7 len(my_list)
# 8 len(s)
# 9 for line in mylog:
#     list1.append(line)
# 10 [int(s) for s in user.split(',')]
# ##SuperVised Starspace###
# 1 b.sort(key=lambda x: x[1][2])
# 2 list_of_dicts.sort(key=operator.itemgetter('age'))
# 3 c2.sort(key=lambda row: (row[2], row[1]))
# 4 l.sort(key=lambda t: len(t[1]), reverse=True)
# 5 list_of_dicts.sort(key=operator.itemgetter('name'))
# 6 c2.sort(key=lambda row: row[2])
# 7 max(lis, key=itemgetter(1))[0]
# 8 c2.sort(key=lambda row: (row[2], row[1], row[0]))
# 9 [mydict[x] for x in mykeys]
# 10 db.GqlQuery('SELECT * FROM Schedule WHERE station = $1', foo.key())
# ##UnsuperVised Starspace###
# 1 [[sum(item) for item in zip(*items)] for items in zip(*data)]
# 2 elements = ['%{0}%'.format(element) for element in elements]
# 3 tuple(l)
# 4 print([item for item in [1, 2, 3]])
# 5 data.reshape(-1, j).mean(axis=1).reshape(data.shape[0], -1)
# 6 list.sort(key=lambda item: (item['points'], item['time']))
# 7 print(sum(row[column] for row in data))
# 8 [index for index, item in enumerate(thelist) if item[0] == '332']
# 9 print(testlist.index(element))
# 10 max(lis, key=lambda item: item[1])[0]
# ##Done###
#
# 491 4918425
# Subtract a value from every number in a list in Python?
# a[:] = [(x - 13) for x in a]
# 5
#
# ##FastText###
# 1 result = ((a for (a, b) in original), (b for (a, b) in original))
# 2 [element for element in lst if isinstance(element, int)]
# 3 result = ([a for (a, b) in original], [b for (a, b) in original])
# 4 [element for element in lst if not isinstance(element, str)]
# 5 [image for menuitem in list_of_menuitems for image in menuitem]
# 6 level1 = map(list, level1)
# 7 {i: d[i] for i in d if i != 'c'}
# 8 """""".join([char for char in 'it is icy' if char != 'i'])
# 9 """""".join([char for char in 'it is icy' if char != 'i'])
# 10 y = [[] for n in range(2)]
# ##SuperVised Starspace###
# 1 list(itertools.combinations((1, 2, 3), 2))
# 2 result = ((a for (a, b) in original), (b for (a, b) in original))
# 3 result = ([a for (a, b) in original], [b for (a, b) in original])
# 4 (n for n in [1, 2, 3, 5])
# 5 c.extend(a)
# 6 a[:] = [(x - 13) for x in a]
# 7 from functools import reduce
# reduce(lambda a, b: a + b, (('aa',), ('bb',), ('cc',)))
# 8 a.extend(list(b))
# 9 generator = iter_iprange('192.168.1.1', '192.168.255.255', step=1)
# 10 re.sub('(\\_a)?\\.([^\\.]*)$', '_suff.\\2', 'long.file.name.jpg')
# ##UnsuperVised Starspace###
# 1 elements = ['%{0}%'.format(element) for element in elements]
# 2 print(sum(row[column] for row in data))
# 3 heapq.nlargest(10, range(len(l1)), key=lambda i: abs(l1[i] - l2[i]))
# 4 next(itertools.islice(range(10), 5, 5 + 1))
# 5 [val for pair in zip(l1, l2) for val in pair]
# 6 print(concatenate((a, b), axis=1))
# 7 tuple(l)
# 8 [sum(row[i] for row in array) for i in range(len(array[0]))]
# 9 print(concatenate((a, b), axis=0))
# 10 from functools import reduce
# reduce(lambda a, b: a + b, (('aa',), ('bb',), ('cc',)))
# ##Done###
#
# 492 701402
# Best way to choose a random file from a directory
# random.choice(os.listdir('C:\\'))
# 8
#
# ##FastText###
# 1 f = open('yourfile.txt', 'w')
# 2 new_file = open('path/to/FILE_NAME.ext', 'w')
# 3 level1 = map(list, level1)
# 4 file = open('Output.txt', 'a')
# 5 print('hi there', file=f)
# 6 result = ((a for (a, b) in original), (b for (a, b) in original))
# 7 Flask(__name__, template_folder='wherever')
# 8 result = ([a for (a, b) in original], [b for (a, b) in original])
# 9 (n for n in [1, 2, 3, 5])
# 10 np.maximum([2, 3, 4], [1, 5, 2])
# ##SuperVised Starspace###
# 1 sys.path.insert(1, os.path.join(os.path.dirname(__file__), 'apps'))
# 2 os.path.basename(os.path.dirname(os.path.realpath(__file__)))
# 3 os.kill(os.getpid(), signal.SIGUSR1)
# 4 os.path.isabs(my_path)
# 5 print(os.path.splitext(os.path.basename('hemanth.txt'))[0])
# 6 sys.path.append(os.path.join(os.path.dirname(__file__), 'subdir'))
# 7 file.seek(0)
# 8 open(filename, 'w').close()
# 9 random.choice(os.listdir('C:\\'))
# 10 os.path.splitext(filename)[0]
# ##UnsuperVised Starspace###
# 1 [k for k, v in list(Counter(mylist).items()) if v > 1]
# 2 (n for n in [1, 2, 3, 5])
# 3 (x[1:] + x[:-1]) / 2
# 4 x[:-1] + (x[1:] - x[:-1]) / 2
# 5 print(l[3:] + l[:3])
# 6 y = [[] for n in range(2)]
# 7 len(set(open(yourdictfile).read().split()))
# 8 res = dict((v, k) for k, v in a.items())
# 9 dict(((x, l.count(x)) for x in set(l)))
# 10 list(dict.keys())[-1]
# ##Done###
#
# 495 30551576
# Using Regular Expressions to extract specific urls in python
# re.findall('http://[^t][^s"]+\\.html', document)
# 1
#
# ##FastText###
# 1 len(s)
# 2 s.encode('iso-8859-15')
# 3 (type(o) is str)
# 4 any(key.startswith('EMP$$') for key in dict1)
# 5 s.split(' ', 4)
# 6 re.findall('\\b(\\w+)d\\b', s)
# 7 re.findall('n(?<=[^n]n)n+(?=[^n])(?i)', s)
# 8 len(my_list)
# 9 print('\n'.join('\t'.join(str(col) for col in row) for row in tab))
# 10 input('Enter your input:')
# ##SuperVised Starspace###
# 1 re.search('(?<!Distillr)\\\\AcroTray\\.exe', 'C:\\SomeDir\\AcroTray.exe')
# 2 re.findall('http://[^t][^s"]+\\.html', document)
# 3 re.findall('\\(.*?\\)|\\w', '(zyx)bc')
# 4 re.findall('\\((.*?)\\)|(\\w)', '(zyx)bc')
# 5 re.findall('\\(.+?\\)|\\w', '(zyx)bc')
# 6 re.findall('(.*?)(?:\\[.*?\\]|$)', example_str)
# 7 re.findall('(.*?)\\[.*?\\]', example_str)
# 8 re.sub('(\\_a)?\\.([^\\.]*)$', '_suff.\\2', 'long.file.name.jpg')
# 9 re.findall('([a-fA-F\\d]{32})', data)
# 10 re.findall('src="js/([^"]*\\bjquery\\b[^"]*)"', data)
# ##UnsuperVised Starspace###
# 1 (type(o) is str)
# 2 my_dict.update({'third_key': 1})
# 3 """ """.join([('%d@%d' % (t[0], t[1])) for t in l])
# 4 [x for x in myfile.splitlines() if x != '']
# 5 print(re.search('(?P<url>https?://[^\\s]+)', myString).group('url'))
# 6 print(re.search('>.*<', line).group(0))
# 7 """ """.join([('%d@%d' % t) for t in l])
# 8 df.groupby(['col1', 'col2'])['col3'].nunique().reset_index()
# 9 {i: d[i] for i in d if i != 'c'}
# 10 matrix = [[a, b], [c, d], [e, f]]
# ##Done###
#
# 499 7635237
# numpy: syntax/idiom to cast (n,) array to a (n, 1) array?
# a[:, (np.newaxis)]
# 6
#
# ##FastText###
# 1 result = ((a for (a, b) in original), (b for (a, b) in original))
# 2 r = requests.post(url, files=files, headers=headers, data=data)
# 3 result = ([a for (a, b) in original], [b for (a, b) in original])
# 4 b = models.CharField(max_length=7, default='0000000', editable=False)
# 5 df.to_csv('c:\\data\\pandas.txt', header=None, index=None, sep=' ', mode='a')
# 6 l = sorted(l, key=lambda a: a['time'], reverse=True)
# 7 level1 = map(list, level1)
# 8 new_file = open('path/to/FILE_NAME.ext', 'w')
# 9 generator = iter_iprange('192.168.1.1', '192.168.255.255', step=1)
# 10 file = open('Output.txt', 'a')
# ##SuperVised Starspace###
# 1 np.where(np.in1d(A, [1, 3, 4]).reshape(A.shape), A, 0)
# 2 numpy.array(a)[0].tolist()
# 3 np.array((a, b))
# 4 numpy.array(a).reshape(-1).tolist()
# 5 np.mean(a, axis=1)
# 6 data.update(a=1)
# 7 a[:, (np.newaxis)]
# 8 np.column_stack(([1, 2, 3], [4, 5, 6]))
# 9 np.array(zip(a.ravel(), b.ravel()), dtype='i4,i4').reshape(a.shape)
# 10 data.reshape(-1, j).mean(axis=1).reshape(data.shape[0], -1)
# ##UnsuperVised Starspace###
# 1 print(concatenate((a, b), axis=1))
# 2 print(concatenate((a, b), axis=0))
# 3 a.sum(axis=1)
# 4 np.mean(a, axis=1)
# 5 df.fillna(df.mean(axis=1), axis=1)
# 6 data.reshape(-1, j).mean(axis=1).reshape(data.shape[0], -1)
# 7 print(sum(row[column] for row in data))
# 8 np.concatenate((A, B))
# 9 np.array(zip(a.ravel(), b.ravel()), dtype='i4,i4').reshape(a.shape)
# 10 [sum(row[i] for row in array) for i in range(len(array[0]))]
# ##Done###
